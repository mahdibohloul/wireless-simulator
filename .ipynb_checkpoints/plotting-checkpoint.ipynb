# %% [markdown]
# # Plotting the data extracted from the simulation

# %% [markdown]
# ### Defining the figure

# %% [markdown]
# To create a graph, we need to fix the bandwidth and construct graphs with the error_rate bars.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('analyzer_result.csv')
df
# Out:
#     bandwidth  error_rate  throughput       ptr     delay
# 0         1.5       0.001    22516.88  0.989573  0.445137
# 1         1.5       0.002    22340.24  0.996309  0.518238
# 2         1.5       0.003    22218.80  0.995550  0.520719
# 3         1.5       0.004    22119.44  0.983562  0.522394
# 4         1.5       0.005    21871.04  0.995480  0.530447
# 5         1.5       0.006    21661.28  0.973469  0.506442
# 6         1.5       0.007    21584.00  0.982915  0.500747
# 7         1.5       0.008    21451.52  0.988810  0.569877
# 8         1.5       0.009    21363.20  0.976791  0.496887
# 9         1.5       0.010    21142.40  0.975064  0.532645
# 10       55.0       0.001    22516.88  0.989573  0.445137
# 11       55.0       0.002    22340.24  0.996309  0.518238
# 12       55.0       0.003    22218.80  0.995550  0.520719
# 13       55.0       0.004    22119.44  0.983562  0.522394
# 14       55.0       0.005    21871.04  0.995480  0.530447
# 15       55.0       0.006    21661.28  0.973469  0.506442
# 16       55.0       0.007    21584.00  0.982915  0.500747
# 17       55.0       0.008    21451.52  0.988810  0.569877
# 18       55.0       0.009    21363.20  0.976791  0.496887
# 19       55.0       0.010    21142.40  0.975064  0.532645
# 20      155.0       0.001    22516.88  0.989573  0.445137
# 21      155.0       0.002    22340.24  0.996309  0.518238
# 22      155.0       0.003    22218.80  0.995550  0.520719
# 23      155.0       0.004    22119.44  0.983562  0.522394
# 24      155.0       0.005    21871.04  0.995480  0.530447
# 25      155.0       0.006    21661.28  0.973469  0.506442
# 26      155.0       0.007    21584.00  0.982915  0.500747
# 27      155.0       0.008    21451.52  0.988810  0.569877
# 28      155.0       0.009    21363.20  0.976791  0.496887
# 29      155.0       0.010    21142.40  0.975064  0.532645

# %% [markdown]
# ## Throughput Analysis

# %% [markdown]
# ### Throughput with bandwidth 1.5MB

# %%
df_1_5 = df[df['bandwidth'] == 1.5]
df_1_5.plot(x='error_rate', y='throughput')
plt.xlabel('Error Rate')
plt.ylabel('Throughput')
plt.title('Throughput with bandwidth 1.5MB')
plt.show()

# %% [markdown]
# ### Throughput with bandwidth 55MB

# %%
df_55 = df[df['bandwidth'] == 55]
df_55.plot(x='error_rate', y='throughput')
plt.xlabel('Error Rate')
plt.ylabel('Throughput')
plt.title('Throughput with bandwidth 55MB')
plt.show()

# %% [markdown]
# ### Throughput with bandwidth 155MB

# %%
df_155 = df[df['bandwidth'] == 155]
df_155.plot(x='error_rate', y='throughput')
plt.xlabel('Error Rate')
plt.ylabel('Throughput')
plt.title('Throughput with bandwidth 155MB')
plt.show()

# %% [markdown]
# ## Packet Transfer Ratio Analysis

# %% [markdown]
# ### Bandwidth 1.5MB

# %%
df_1_5 = df[df['bandwidth'] == 1.5]
df_1_5.plot(x='error_rate', y='ptr')
plt.xlabel('Error Rate')
plt.ylabel('Packet Transfer Ratio')
plt.title('Packet Transfer Ratio with bandwidth 1.5MB')
plt.show()

# %% [markdown]
# ### Bandwidth 55MB

# %%
df_55 = df[df['bandwidth'] == 55]
df_55.plot(x='error_rate', y='ptr')
plt.xlabel('Error Rate')
plt.ylabel('Packet Transfer Ratio')
plt.title('Packet Transfer Ratio with bandwidth 55MB')
plt.show()

# %% [markdown]
# ### Bandwidth 155MB

# %%
df_155 = df[df['bandwidth'] == 155]
df_155.plot(x='error_rate', y='ptr')
plt.xlabel('Error Rate')
plt.ylabel('Packet Transfer Ratio')
plt.title('Packet Transfer Ratio with bandwidth 155MB')
plt.show()

# %% [markdown]
# ## Delay Analysis

# %% [markdown]
# ### Delay with bandwidth 1.5MB

# %%
df_1_5 = df[df['bandwidth'] == 1.5]
df_1_5.plot(x='error_rate', y='delay')
plt.xlabel('Error Rate')
plt.ylabel('Delay')
plt.title('Delay with bandwidth 1.5MB')
plt.show()

# %% [markdown]
# ### Delay with bandwidth 55MB

# %%
df_55 = df[df['bandwidth'] == 55]
df_55.plot(x='error_rate', y='delay')
plt.xlabel('Error Rate')
plt.ylabel('Delay')
plt.title('Delay with bandwidth 55MB')
plt.show()

# %% [markdown]
# ### Delay with bandwidth 155MB

# %%
df_155 = df[df['bandwidth'] == 155]
df_155.plot(x='error_rate', y='delay')
plt.xlabel('Error Rate')
plt.ylabel('Delay')
plt.title('Delay with bandwidth 155MB')
plt.show()
